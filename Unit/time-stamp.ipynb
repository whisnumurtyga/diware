# %%
import cv2

cap = cv2.VideoCapture(0)  # Ganti dengan lokasi video Anda

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    timestamp_milliseconds = cap.get(cv2.CAP_PROP_POS_MSEC)
    timestamp_seconds = timestamp_milliseconds / 1000.0
    
    print("Timestamp (milliseconds):", timestamp_milliseconds)
    print("Timestamp (seconds):", timestamp_seconds)
    
    cv2.imshow('Frame', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Timestamp (milliseconds): 23479231.3608
# Timestamp (seconds): 23479.2313608
# Timestamp (milliseconds): 23479264.6941
# Timestamp (seconds): 23479.2646941
# Timestamp (milliseconds): 23479298.0275
# Timestamp (seconds): 23479.2980275
# Timestamp (milliseconds): 23479331.3608
# Timestamp (seconds): 23479.331360800003
# Timestamp (milliseconds): 23479364.6941
# Timestamp (seconds): 23479.3646941
# Timestamp (milliseconds): 23479398.0275
# Timestamp (seconds): 23479.3980275
# Timestamp (milliseconds): 23479431.3608
# Timestamp (seconds): 23479.4313608
# Timestamp (milliseconds): 23479464.6941
# Timestamp (seconds): 23479.4646941
# Timestamp (milliseconds): 23479498.0275
# Timestamp (seconds): 23479.4980275
# Timestamp (milliseconds): 23479531.3608
# Timestamp (seconds): 23479.531360800003
# Timestamp (milliseconds): 23479564.6941
# Timestamp (seconds): 23479.5646941
# Timestamp (milliseconds): 23479598.0275
# Timestamp (seconds): 23479.5980275
# Timestamp (milliseconds): 23479631.3608
# ...

# %%
cv2.destroyAllWindows()
